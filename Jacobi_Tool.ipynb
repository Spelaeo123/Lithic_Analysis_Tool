# %% [markdown]
# # Jacobi Lithic Analysis Data Entry Tool

# %% [markdown]
# ## Import libraries and modules

# %%
import os
import sys
import PySimpleGUI as sg
import pandas as pd
import textwrap as wrap
import openpyxl
import tkinter as tk
from openpyxl import load_workbook

# %%
# Unfuzzy text (cannot implement until there is an option to increase the size of the Radio button object)

# %%
import ctypes
import platform

def make_dpi_aware():
    if int(platform.release()) == 10:
        ctypes.windll.shcore.SetProcessDpiAwareness(True)

make_dpi_aware()

# %% [markdown]
# ## Import input/output file

# %% [markdown]
# ## Columns in excel file

# %%
cols = ['SF Number', 'Site', 'Category', 'Subcategory','Post-deposition damage', 'Cortication type', 'Butt type', 'Cortex type', 'Cortex thickness', 'Breakage', 'Flaking Pattern', 'Profile' ,'Weight (g)', 'Length (mm)', 'Width (mm)', 'Breadth (mm)', 'p_Width (mm)', 'p_Breadth (mm)', 'Other details']

# %% [markdown]
# ## Attribute Lists

# %%
lst = ('1. Site 1','2. Site 2','3. Site 3','4. Site 4','5. Site 5','6. Site 6','7. Site 7','8. Other')
CatLst = ('1. Flake', '2. Blade', '3. Bladelet','4. Blake-like flake (DO NOT USE)','5. Irregular Waste','6. Chip','7. Microburin','8. Burin spall','9. Rejuvenation flake','10. Core tablet','11. Rejuvenation flake other','12. Levallois flake','13. Janus flake (= thinning)','14. Axe working flake','15. Flake from ground implement','16. Single platform blade core','17. Opposed platform blade core','18. Other Blade core','19. Tested nodule/ bashed lump','20. Single platform flake core','21. Multiplatform flake core','22. Keeled non-discoidal flake core','23. Levallois/ other discoidal flake core','24. Unclassifiable/ fragmentary core','25. Microlith','26. Petit tranchet arrowhead','27. Leaf arrowhead','28. Chisel arrowhead','29. Oblique arrowhead','30. Barbed and tanged arrowhead','31. Triangular arrowhead','32. Hollow-based arrowhead','33. Laurel leaf','34. Unfinished arrowhead/blank','35. Fragmentary/unclass/other arrowhead','36. End scraper','37. Side scraper','38. End and side scraper','39. Disc scraper','40. Thumbnail scraper','41. Scraper on a non-flake blank','42. Other scraper','43. Awl','44. Piercer','45. Spurred piece','46. Other borer','47. Serrated flake','48. Saw','49. Denticulate','50. Notch','51. Backed knife','52. Scale flaked knife','53. Plano-convex knife','54. Other knife','55. Flake retouched','56. Single-piece sickle','57. Fabricator','58. Axe','59. Other heavy implement','60. Misc retouch','61. Other retouch','62. Burnt unworked','63. Hammerstone','64. Natural','65. Core on a flake','66. Gun flint','67. Axe sharpening flake','68. Sieved chips 10-4mm','69. Sieved chips 4-2mm','70. Sieved chips','71. Bruised blade/flake','72. Burin','73. Blade crested','74. Blade retouched','75. End truncation straight','76. End truncation oblique','77. Backed bladelet','78. Bipolar core')
lst2 = ('1. Fresh','2. Slight', '3. Moderate','4. Heavy','5. Plough damaged','6. Rolled','7. Glossed','8. Modern damage')
lst3 = ('1. None','2. Light','3. Moderate','4. Heavy','5. Very heavy','6. Iron stained')
lst4 = ('1. Cortical (cortex)','2. Plain ','3. Dihedral','4. Faceted','5. Linear','6. Shattered','7. Thermal','8. Punctiform','9. Modified','10. Indeterminate')
lst5 = ('1. Chalk – thick', '2. Weathered Chalk','3. Weathered','4. Rolled','5. Thermal','6. Indeterminate','7. Banded')
lst6 = ('1. Thin – <2mm thick', '2. Moderate 2-4mm', '3. Thick 4-10mm', '4. Very thick, >10mm')
lst7 = ('1. Proximal', '2. Distal', '3. Medial', '4. Left lateral', '5. Right lateral')
lst8 = ('1. No mode', '2. Unimodal', '3. Opposed', '4. Crossed', '5. Mixed')
lst9 = ('1. Straight', '2. Curved', '3. Twisted')

# %%
SubCatLst = {
    '1. Flake': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '2. Blade': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '3. Bladelet': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    #'4. Blake-like flake (DO NOT USE)',
    #'5. Irregular Waste',
    #'6. Chip',
    #'7. Microburin',
    #'8. Burin spall',
    '9. Rejuvenation flake': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '10. Core tablet': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '11. Rejuvenation flake other': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '12. Levallois flake': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '13. Janus flake (= thinning)': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '14. Axe working flake': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '15. Flake from ground implement': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    #'16. Single platform blade core',
    #'17. Opposed platform blade core',
    #'18. Other Blade core',
    #'19. Tested nodule/ bashed lump',
    #'20. Single platform flake core',
    #'21. Multiplatform flake core',
    #'22. Keeled non-discoidal flake core',
    #'23. Levallois/ other discoidal flake core',
    #'24. Unclassifiable/ fragmentary core',
    '25. Microlith': ['1a-Obliquely Blunted Point','1b-Obliquely Blunted Point','1ac-Obliquely Blunted Point','1bc-Obliquely Blunted Point','2a-Isoceles Triangle','2as-Isoceles Triangle','2b-Trapeze','3a-Bi-truncated Rhombic Point','3b-Rhombic Point','3c-Convex Backed Point','3d-Convex Backed Point','4-Convex Backed Point','5-Straight-backed bladelet','5b-Straight-backed bladelet','5c-Asymetric Micro Tranchet','5d-Micro Tranchet','5e-Micro Tranchet','6-Rod','6b-Pear shaped','6c-Boat-shaped','7a1-Narrow Scalene Microtriangle','7a2-Narrow Scalene Microtriangle','8-Microrhomboid','9-Microlunate','10a-Horsham Point','10b-Horsham Point','10c-Horsham Point','11-Symmetrical Microlith/Honey Hill','12-Asymmetrical microlith','13-Asymmetrical microlith'],
    #'26. Petit tranchet arrowhead',
    #'27. Leaf arrowhead',
    #'28. Chisel arrowhead',
    #'29. Oblique arrowhead',
    #'30. Barbed and tanged arrowhead',
    #'31. Triangular arrowhead',
    #'32. Hollow-based arrowhead',
    #'33. Laurel leaf',
    #'34. Unfinished arrowhead/blank',
    #'35. Fragmentary/unclass/other arrowhead',
    '36. End scraper': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '37. Side scraper': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '38. End and side scraper': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '39. Disc scraper': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '40. Thumbnail scraper': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '41. Scraper on a non-flake blank': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '42. Other scraper': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '43. Awl': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '44. Piercer': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '45. Spurred piece': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '46. Other borer': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '47. Serrated flake': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '48. Saw': ['inner', 'side trimming', 'distal trimming','misc trimming', 'preparation'],
    '49. Denticulate': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '50. Notch': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '51. Backed knife': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '52. Scale flaked knife': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '53. Plano-convex knife': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '54. Other knife': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '55. Flake retouched': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '56. Single-piece sickle': ['inner', 'side trimming', 'distal trimming', 'misc trimming', 'preparation'],
    '57. Fabricator': ['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    #'58. Axe',
    #'59. Other heavy implement',
    #'60. Misc retouch',
    #'61. Other retouch',
    #'62. Burnt unworked',
    #'63. Hammerstone',
    #'64. Natural',
    #'65. Core on a flake',
    #'66. Gun flint',
    #'67. Axe sharpening flake': ['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    #'68. Sieved chips 10-4mm',
    #'69. Sieved chips 4-2mm',
    #'70. Sieved chips',
    #'71. Bruised blade/flake',
    #'72. Burin',
    #'73. Blade/Flake crested',
    '74. Blade retouched': ['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    '75. End truncation straight': ['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    '76. End truncation oblique':['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    '77. Backed bladelet': ['inner', 'side trimming', 'distal trimming',	'misc trimming', 'preparation'],
    #'78. Bipolar core'
}

responses = []

# %% [markdown]
# ## Column sizes

# %%
colsize = [20,30]

# %% [markdown]
# ## Font sizes

# %%
hfont = ("Calibri", 10)
font = ("Calibri", 8)

# %% [markdown]
# ## Columns layout

# %%
#Main column containing the majority of elements to be recorded
MainCol = [

#Select output file
[sg.Text('Select output file:', font=hfont), sg.Input(),sg.FilesBrowse(file_types=(("xlsx files", "*.xlsx"), ("csv files", "*.csv*")), key='-IN-')],

#Title
[sg.Text('Please fill the following fields:', font=hfont)],
[sg.Text('SF Number', size=(15,1), font=hfont), sg.InputText(key='SF_Number')],
    
#Select Site
[sg.Text('Site:', font=hfont)],
[sg.Radio(text, "Radio", enable_events=True, key=f"Radio1 {i}", font=font) for i, text in enumerate(lst)],

#Select Category
[sg.Text('Category', size=(15,1), font=hfont)], 
[sg.Combo(['1. Flake', '2. Blade', '3. Bladelet','4. Blake-like flake (DO NOT USE)','5. Irregular Waste','6. Chip','7. Microburin','8. Burin spall','9. Rejuvenation flake','10. Core tablet','11. Rejuvenation flake other','12. Levallois flake','13. Janus flake (= thinning)','14. Axe working flake','15. Flake from ground implement','16. Single platform blade core','17. Opposed platform blade core','18. Other Blade core','19. Tested nodule/ bashed lump','20. Single platform flake core','21. Multiplatform flake core','22. Keeled non-discoidal flake core','23. Levallois/ other discoidal flake core','24. Unclassifiable/ fragmentary core','25. Microlith','26. Petit tranchet arrowhead','27. Leaf arrowhead','28. Chisel arrowhead','29. Oblique arrowhead','30. Barbed and tanged arrowhead','31. Triangular arrowhead','32. Hollow-based arrowhead','33. Laurel leaf','34. Unfinished arrowhead/blank','35. Fragmentary/unclass/other arrowhead','36. End scraper','37. Side scraper','38. End and side scraper','39. Disc scraper','40. Thumbnail scraper','41. Scraper on a non-flake blank','42. Other scraper','43. Awl','44. Piercer','45. Spurred piece','46. Other borer','47. Serrated flake','48. Saw','49. Denticulate','50. Notch','51. Backed knife','52. Scale flaked knife','53. Plano-convex knife','54. Other knife','55. Flake retouched','56. Single-piece sickle','57. Fabricator','58. Axe','59. Other heavy implement','60. Misc retouch','61. Other retouch','62. Burnt unworked','63. Hammerstone','64. Natural','65. Core on a flake','66. Gun flint','67. Axe sharpening flake','68. Sieved chips 10-4mm','69. Sieved chips 4-2mm','70. Sieved chips','71. Bruised blade/flake','72. Burin','73. Blade crested','74. Blade retouched','75. End truncation straight','76. End truncation oblique','77. Backed bladelet','78. Bipolar core'], key='Category', enable_events=True)],

#Select Post-deposition damage
[sg.Text('Post-deposition damage:', font=hfont)],
[sg.Radio(text, "Radio2", enable_events=True, key=f"Radio2 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst2)],

#Select Cortication
[sg.Text('Cortication/ patination type:', font=hfont)],
[sg.Radio(text, "Radio3", enable_events=True, key=f"Radio3 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst3)],

#Select Butt type
[sg.Text('Butt type:', font=hfont)],
[sg.Radio(text, "Radio4", enable_events=True, key=f"Radio4 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst4)],

#Select Cortex type 
[sg.Text('Cortex type:', font=hfont)], 
[sg.Radio(text, "Radio5", enable_events=True, key=f"Radio5 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst5)],

#Select Cortex thickness
[sg.Text('Cortex thickness:', font=hfont)], 
[sg.Radio(text, "Radio6", enable_events=True, key=f"Radio6 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst6)],

#Select Cortex thickness
[sg.Text('Breakage:', font=hfont)], 
[sg.Radio(text, "Radio7", enable_events=True, key=f"Radio7 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst7)],

#Select Cortex thickness
[sg.Text('Flaking pattern:', font=hfont)], 
[sg.Radio(text, "Radio8", enable_events=True, key=f"Radio8 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst8)],

#Select Cortex thickness
[sg.Text('Profile:', font=hfont)], 
[sg.Radio(text, "Radio9", enable_events=True, key=f"Radio9 {i}", size=15, font=font, pad=0) for i, text in enumerate(lst9)],

]    

#First column for numerical details to be entered
NumInputCol = [

#Enter weight
[sg.Text('Weight (g)', size=(15,1), font=hfont),sg.Input('', key='Weight')],
    
#Enter length
[sg.Text('Length (mm)', size=(15,1), font=hfont),sg.Input('', key='Length')],
    
#Enter width
[sg.Text('Width (mm)', size=(15,1), font=hfont),sg.Input('', key='Width')],
    
#Enter breadth
[sg.Text('Breadth (mm)', size=(15,1), font=hfont),sg.Input('', key='Breadth')],
    
]

#Second column for numerical details to be entered
NumInputCol2 = [
    
#Enter p_width
[sg.Text('p_width (mm)', size=(15,1), font=hfont),sg.Input('', key='pWidth')],
    
#Enter p_breath
[sg.Text('p_breadth (mm)', size=(15,1), font=hfont),sg.Input('', key='pBreadth')],
    
#Enter any other comments
[sg.Text('Other comments:', size=(15,1), font=hfont),sg.Input('', key='Other Details')],
    
]

#Submit, Clear, and Exit column
SubmitExitCol = [[sg.Push(),sg.Button("Submit"),sg.Button("Clear"),sg.Button('Exit')]]

# %% [markdown]
# ## Layout and window

# %%
layout = [
    [
        sg.Column(MainCol)
    ],
    [
        sg.Column(NumInputCol),
        sg.Column(NumInputCol2)
    ],
    [
        sg.Column(SubmitExitCol)
    ]
]    


scrollable_layout = [[sg.Column(layout, size=(None, None), expand_x=True, expand_y=True, scrollable=True)]]

window = sg.Window("Jacobi: Lithic Analyis Data Entry Tool v0.5", scrollable_layout, resizable=True, element_justification='l', finalize=True)

print(layout)
# Out:
# [[<PySimpleGUI.PySimpleGUI.Column object at 0x000002D5F4FD9F10>], [<PySimpleGUI.PySimpleGUI.Column object at 0x000002D5F4FD9EE0>, <PySimpleGUI.PySimpleGUI.Column object at 0x000002D5F4FD9E20>], [<PySimpleGUI.PySimpleGUI.Column object at 0x000002D5F4FD9DC0>]]

# %% [markdown]
# ## clear input function

# %%
def clear_input():
    keys_to_clear = ["SF_Number","Category","Weight","Length","Width","Breadth","pWidth","pBreadth","Other Details"]
    for key in keys_to_clear:
        window[key]('')
    window["Radio1 0"].reset_group()
    window["Radio2 0"].reset_group()
    window["Radio3 0"].reset_group()
    window["Radio4 0"].reset_group()
    window["Radio5 0"].reset_group()
    window["Radio6 0"].reset_group()
    window["Radio7 0"].reset_group()
    window["Radio8 0"].reset_group()
    window["Radio9 0"].reset_group()
    return None

# %% [markdown]
# ## While statement

# %% [markdown]
# while True:
#     event, values = window.read()
#     if event in (sg.WINDOW_CLOSED, 'Exit'):
#         break
#     if event == 'Clear':
#         clear_input()
#     elif event == 'Submit':
#         filename = values['-IN-']
#
#         radio_value = window['Radio1 0'].TKIntVar.get()
#         text = lst[radio_value % 1000] if radio_value is not None else None
#
#         radio_value2 = window['Radio2 0'].TKIntVar.get()
#         text2 = lst2[radio_value2 % 1000] if radio_value2 is not None else None
#         text2 = int(text2[0])
#
#         radio_value3 = window['Radio3 0'].TKIntVar.get()
#         text3 = lst3[radio_value3 % 1000] if radio_value3 is not None else None
#         text3 = int(text3[0])
#
#         radio_value4 = window['Radio4 0'].TKIntVar.get() #lst4 goes up to 10 options, so needs the code to
#         text4 = lst4[radio_value4 % 1000] if radio_value4  is not None else None
#         text4 = text4[:2]
#         text4 = text4.replace(".", "")
#         text4 = int(text4)
#
#         radio_value5 = window['Radio5 0'].TKIntVar.get()
#         text5 = lst5[radio_value5 % 1000] if radio_value5 is not None else None
#         text5 = int(text5[0])
#
#         radio_value6 = window['Radio6 0'].TKIntVar.get()
#         text6 = lst6[radio_value6 % 1000] if radio_value6 is not None else None
#         text6 = text6[0]
#         text6 = int(text6[0])
#
#         radio_value7 = window['Radio7 0'].TKIntVar.get()
#         text7 = lst7[radio_value7 % 1000] if radio_value7 is not None else None
#         text7 = text7[0]
#         text7 = int(text7[0])
#
#         radio_value8 = window['Radio8 0'].TKIntVar.get()
#         text8 = lst8[radio_value8 % 1000] if radio_value8 is not None else None
#         text8 = text8[0]
#         text8 = int(text8[0])
#
#         radio_value9 = window['Radio9 0'].TKIntVar.get()
#         text9 = lst9[radio_value9 % 1000] if radio_value9 is not None else None
#         text9 = text9[0]
#         text9 = int(text9[0])
#
#         cat_num = values['Category']
#         cat_num = cat_num[:2]
#         cat_num = cat_num.replace(".", "")
#         cat_num = int(cat_num)
#
#         weight_num = values['Weight']
#         len_num = values['Length']
#         width_num = values['Width']
#         breadth_num = values['Breadth']
#         pWidth_num = values['pWidth']
#         pBreadth_num = values['pBreadth']
#
#         #cols = ['SF Number', 'Site', 'Category', 'Post-deposition damage', 'Cortication type', 'Butt type', 'Cortex type', 'Cortex thickness', 'Breakage', 'Flaking Pattern', 'Profile' ,'Weight (g)', 'Length (mm)', 'Width (mm)', 'Breadth (mm)', 'p_Width (mm)', 'p_Breadth (mm)', 'Other details']
#         record = [values['SF_Number'], text, cat_num, text2, text3, text4, text5, text6, text7, text8, text9, weight_num, len_num, width_num, breadth_num, pWidth_num, pBreadth_num, values['Other Details']]
#         print(record)
#         df_record = pd.DataFrame([record], columns=cols)
#         print(df_record)
#         df = pd.read_excel(filename, engine="openpyxl")
#         df = df.append(df_record, ignore_index=True, sort=False)
#         print(df)
#         with pd.ExcelWriter(filename, engine="openpyxl", mode="w") as writer:
#             df.to_excel(writer, index=False)
#             writer.save()
#         #writer.close()
#         sg.popup('Data saved!')
#         clear_input()
#
# window.close()
# #sys.exit()

# %% [markdown]
# def get_radio_value(window, radio_name, radio_data_list):
#     radio_value = window[radio_name].TKIntVar.get()
#     if radio_value is not None:
#         selected_radio_data = radio_data_list[radio_value % 1000]
#         selected_text_part = selected_radio_data.split('.')[0]
#         return int(selected_text_part)
#     return None
#
# def get_input_value(values, key):
#     value = values[key]
#     if value:
#         return value
#     return None
#
# while True:
#     event, values = window.read()
#     if event in (sg.WINDOW_CLOSED, 'Exit'):
#         break
#     if event == 'Clear':
#         clear_input()
#     elif event == 'Submit':
#         filename = values['-IN-']
#
#         text = get_radio_value(window, 'Radio1 0', lst)
#         text2 = get_radio_value(window, 'Radio2 0', lst2)
#         text3 = get_radio_value(window, 'Radio3 0', lst3)
#         text4 = get_radio_value(window, 'Radio4 0', lst4)
#         text5 = get_radio_value(window, 'Radio5 0', lst5)
#         text6 = get_radio_value(window, 'Radio6 0', lst6)
#         text7 = get_radio_value(window, 'Radio7 0', lst7)
#         text8 = get_radio_value(window, 'Radio8 0', lst8)
#         text9 = get_radio_value(window, 'Radio9 0', lst9)
#
#         #Get the number of the category selected
#         cat_num_text = values['Category']
#         if cat_num_text:
#             cat_num = int(cat_num_text.split('.')[0])
#         else:
#             cat_num = None
#
#         #Get the value entered for the text fields
#         sf_num = get_input_value(values, 'SF_Number')
#         weight_num = get_input_value(values, 'Weight')
#         len_num = get_input_value(values, 'Length')
#         width_num = get_input_value(values, 'Width')
#         breadth_num = get_input_value(values, 'Breadth')
#         pWidth_num = get_input_value(values, 'pWidth')
#         pBreadth_num = get_input_value(values, 'pBreadth')
#         other_details = get_input_value(values, 'Other Details')
#
#         #cols = ['SF Number', 'Site', 'Category', 'Post-deposition damage', 'Cortication type', 'Butt type', 'Cortex type', 'Cortex thickness', 'Breakage', 'Flaking Pattern', 'Profile' ,'Weight (g)', 'Length (mm)', 'Width (mm)', 'Breadth (mm)', 'p_Width (mm)', 'p_Breadth (mm)', 'Other details']
#         record = [sf_num, text, cat_num, text2, text3, text4, text5, text6, text7, text8, text9, weight_num, len_num, width_num, breadth_num, pWidth_num, pBreadth_num, other_details]
#
#         #Convert record into a pandas dataframe
#         df_record = pd.DataFrame([record], columns=cols)
#
#         # Read existing data
#         df_existing = pd.read_excel(filename, engine="openpyxl")
#
#         # Append the new record to the existing DataFrame
#         df_updated = pd.concat([df_existing, df_record], ignore_index=True, sort=False)
#
#         try:
#             # Write the updated DataFrame back to the same Excel file
#             with pd.ExcelWriter(filename, engine="openpyxl", mode="w") as writer:
#                 df_updated.to_excel(writer, index=False, encoding='utf-8')
#
#             # Notify the user
#             sg.popup('Data saved!')
#             clear_input()
#
#         except PermissionError:
#             sg.popup_error('The file is currently open. Please close it and try again.')
#         except Exception as e:
#             sg.popup_error(f'An error occurred: {e}')
#
#         # Write the updated DataFrame back to the same Excel file
#         #with pd.ExcelWriter(filename, engine="openpyxl", mode="w") as writer:
#         #    df_updated.to_excel(writer, index=False, encoding='utf-8')
#
#         # Notify the user
#         #sg.popup('Data saved!')
#         #clear_input()
#
# window.close()

# %%
def get_radio_value(window, radio_name, radio_data_list):
    radio_value = window[radio_name].TKIntVar.get()
    if radio_value is not None:
        selected_radio_data = radio_data_list[radio_value % 1000]
        selected_text_part = selected_radio_data.split('.')[0]
        return int(selected_text_part)
    return None

def get_input_value(values, key):
    value = values[key]
    if value:
        return value
    return None

while True:
    event, values = window.read()
    if event in (sg.WINDOW_CLOSED, 'Exit'):
        break
    if event == 'Clear':
        clear_input()
    if event == 'Category':
        print(f"Event: {event}")
        selected_option = values['Category']
        sub_category_list = SubCatLst.get(selected_option)

        if sub_category_list:
            subcat_popup_layout = [
                [sg.Text('Select a sub-category:')],
                [sg.Combo(sub_category_list, key='-SUB_COMBO-')],
                [sg.Button('OK')]
            ]

            subcat_popup_window = sg.Window('Sub-Category Window', subcat_popup_layout)

            while True:
                subcat_event, subcat_values = subcat_popup_window.read()
                if subcat_event == sg.WINDOW_CLOSED:
                    break
                elif subcat_event == 'OK':
                    selected_subcategory = subcat_values.get('-SUB_COMBO-')
                    responses.append(selected_subcategory)
                    break

            subcat_popup_window.close()
        else:
            # Handle the case where there's no sub-category list
            responses = []
            
    elif event == 'Submit':
        filename = values['-IN-']
        
        text = get_radio_value(window, 'Radio1 0', lst)
        text2 = get_radio_value(window, 'Radio2 0', lst2)
        text3 = get_radio_value(window, 'Radio3 0', lst3)
        text4 = get_radio_value(window, 'Radio4 0', lst4)
        text5 = get_radio_value(window, 'Radio5 0', lst5)
        text6 = get_radio_value(window, 'Radio6 0', lst6)
        text7 = get_radio_value(window, 'Radio7 0', lst7)
        text8 = get_radio_value(window, 'Radio8 0', lst8)
        text9 = get_radio_value(window, 'Radio9 0', lst9)

        #Get the number of the category selected
        cat_num_text = values['Category']
        if cat_num_text:
            cat_num = int(cat_num_text.split('.')[0])
        else:
            cat_num = None
            
        #Get sub category value
        if responses:
            responses_final = responses[0].split('-')[0]
        else:
            responses_final = None
        
        #Get the value entered for the text fields
        sf_num = get_input_value(values, 'SF_Number')
        weight_num = get_input_value(values, 'Weight')
        len_num = get_input_value(values, 'Length')
        width_num = get_input_value(values, 'Width')
        breadth_num = get_input_value(values, 'Breadth')
        pWidth_num = get_input_value(values, 'pWidth')
        pBreadth_num = get_input_value(values, 'pBreadth')
        other_details = get_input_value(values, 'Other Details')
        
        #cols = ['SF Number', 'Site', 'Category', 'Post-deposition damage', 'Cortication type', 'Butt type', 'Cortex type', 'Cortex thickness', 'Breakage', 'Flaking Pattern', 'Profile' ,'Weight (g)', 'Length (mm)', 'Width (mm)', 'Breadth (mm)', 'p_Width (mm)', 'p_Breadth (mm)', 'Other details']
        record = [sf_num, text, cat_num, responses_final, text2, text3, text4, text5, text6, text7, text8, text9, weight_num, len_num, width_num, breadth_num, pWidth_num, pBreadth_num, other_details]
        
        #Convert record into a pandas dataframe
        df_record = pd.DataFrame([record], columns=cols)

        # Read existing data
        df_existing = pd.read_excel(filename, engine="openpyxl")

        # Append the new record to the existing DataFrame
        df_updated = pd.concat([df_existing, df_record], ignore_index=True, sort=False)
        
        try:
            # Write the updated DataFrame back to the same Excel file
            with pd.ExcelWriter(filename, engine="openpyxl", mode="w") as writer:
                df_updated.to_excel(writer, index=False, encoding='utf-8')
        
            # Notify the user
            sg.popup('Data saved!')
            clear_input()

        except PermissionError:
            sg.popup_error('The file is currently open. Please close it and try again.')
        except Exception as e:
            sg.popup_error(f'An error occurred: {e}')

        # Write the updated DataFrame back to the same Excel file
        #with pd.ExcelWriter(filename, engine="openpyxl", mode="w") as writer:
        #    df_updated.to_excel(writer, index=False, encoding='utf-8')

        # Notify the user
        #sg.popup('Data saved!')
        #clear_input()

window.close()
# Out:
# Event: Category
# Event: Category
