# %%
###### import PySimpleGUI as sg
import pandas as pd
import PySimpleGUI as sg

# Add some color to the window
sg.theme('DarkTeal9')

EXCEL_FILE = 'data_entry.xlsx'
df = pd.read_excel(EXCEL_FILE)

SiteLst = ('Site 1','Site 2','Site 3','Site 4','Site 5','Site 6','Site 7','Other')
CatLst = ('1. Flake', '2. Blade', '3. Bladelet','4. Blake-like flake (DO NOT USE)','5. Irregular Waste','6. Chip','7. Microburin','8. Burin spall','9. Rejuvenation flake','10. Core tablet','11. Rejuvenation flake other','12. Levallois flake','13. Janus flake (= thinning)','14. Axe working flake','15. Flake from ground implement','16. Single platform blade core','17. Opposed platform blade core','18. Other Blade core','19. Tested nodule/ bashed lump','20. Single platform flake core','21. Multiplatform flake core','22. Keeled non-discoidal flake core','23. Levallois/ other discoidal flake core','24. Unclassifiable/ fragmentary core','25. Microlith','26. Petit tranchet arrowhead','27. Leaf arrowhead','28. Chisel arrowhead','29. Oblique arrowhead','30. Barbed and tanged arrowhead','31. Triangular arrowhead','32. Hollow-based arrowhead','33. Laurel leaf','34. Unfinished arrowhead/blank','35. Fragmentary/unclass/other arrowhead','36. End scraper','37. Side scraper','38. End and side scraper','39. Disc scraper','40. Thumbnail scraper','41. Scraper on a non-flake blank','42. Other scraper','43. Awl','44. Piercer','45. Spurred piece','46. Other borer','47. Serrated flake','48. Saw','49. Denticulate','50. Notch','51. Backed knife','52. Scale flaked knife','53. Plano-convex knife','54. Other knife','55. Flake retouched','56. Single-piece sickle','57. Fabricator','58. Axe','59. Other heavy implement','60. Misc retouch','61. Other retouch','62. Burnt unworked','63. Hammerstone','64. Natural','65. Core on a flake','66. Gun flint','67. Axe sharpening flake','68. Sieved chips 10-4mm','69. Sieved chips 4-2mm','70. Sieved chips','71. Bruised blade/flake','72. Burin','73. Blade crested','74. Blade retouched','75. End truncation straight','76. End truncation oblique','77. Backed bladelet','78. Bipolar core')
PDepLst = ('1. Fresh','2. Slight post depositional damage', '3. Moderate post depositional damage','4. Heavy post depositional damage','5. Plough damaged','6. Rolled','7. Glossed','8. Modern damage')
CortLst = ('1. No cortication','2. Light cortication','3. Moderate cortication','4. Heavy cortication','5. Very heavy cortication','6. Iron stained')
ButtLst = ('1. Cortical (cortex)','2. Plain (unaltered inner flint)','3. Dihedral (2 scars)','4. Faceted (more than 2 scars)','5. Linear (very narrow and usually quite long)','6. Shattered','7. Thermal (old recorticated or patinated surface)','8. Punctiform','9. Modified (retouched or otherwise altered)','10. Indeterminate (if you can’t decide or it doesn’t fit any of the above)')
CortypeLst = ('1. Chalk – thick, creamy white, chalky', '2. Weathered Chalk – like above but clearly worn and probably thin or moderate in thickness','3. Weathered – Similar to WC above, will be rough to the touch but clearly ground down.','4. Rolled – typical beach pebble/ river gravel flint, smooth','5. Thermal – re-corticated old surface, often will be in','6. Indeterminate','7. Banded -eg. Bullhead flint')
CorThickLst = ('1. Thin – up to 2mm thick (judge don’t measure)', '2. Moderate 2-4mm thickness', '3. Thick 4-10mm', '4. Very thick, greater than 10mm')

layout = [
    [sg.Text('Please fill out the following fields:')],
    [sg.Text('SF Number', size=(15,1)), sg.InputText(key='SF_Number')],
    [sg.Text('Select Site:')],
    [sg.Radio(text, "Radio", enable_events=True, key=f"RadioSite {i}")
        for i, text in enumerate(SiteLst)],
    [sg.Text('Category', size=(15,1)), sg.Combo(['1. Flake', '2. Blade', '3. Bladelet','4. Blake-like flake (DO NOT USE)','5. Irregular Waste','6. Chip','7. Microburin','8. Burin spall','9. Rejuvenation flake','10. Core tablet','11. Rejuvenation flake other','12. Levallois flake','13. Janus flake (= thinning)','14. Axe working flake','15. Flake from ground implement','16. Single platform blade core','17. Opposed platform blade core','18. Other Blade core','19. Tested nodule/ bashed lump','20. Single platform flake core','21. Multiplatform flake core','22. Keeled non-discoidal flake core','23. Levallois/ other discoidal flake core','24. Unclassifiable/ fragmentary core','25. Microlith','26. Petit tranchet arrowhead','27. Leaf arrowhead','28. Chisel arrowhead','29. Oblique arrowhead','30. Barbed and tanged arrowhead','31. Triangular arrowhead','32. Hollow-based arrowhead','33. Laurel leaf','34. Unfinished arrowhead/blank','35. Fragmentary/unclass/other arrowhead','36. End scraper','37. Side scraper','38. End and side scraper','39. Disc scraper','40. Thumbnail scraper','41. Scraper on a non-flake blank','42. Other scraper','43. Awl','44. Piercer','45. Spurred piece','46. Other borer','47. Serrated flake','48. Saw','49. Denticulate','50. Notch','51. Backed knife','52. Scale flaked knife','53. Plano-convex knife','54. Other knife','55. Flake retouched','56. Single-piece sickle','57. Fabricator','58. Axe','59. Other heavy implement','60. Misc retouch','61. Other retouch','62. Burnt unworked','63. Hammerstone','64. Natural','65. Core on a flake','66. Gun flint','67. Axe sharpening flake','68. Sieved chips 10-4mm','69. Sieved chips 4-2mm','70. Sieved chips','71. Bruised blade/flake','72. Burin','73. Blade crested','74. Blade retouched','75. End truncation straight','76. End truncation oblique','77. Backed bladelet','78. Bipolar core'], key='Category')],

#    [sg.Radio(text, "Radio1", enable_events=True, key=f"Radio1 {i}")
#        for i, text in enumerate(CatLst)],
    
#Post-deposition damage
    [sg.Text('Select Post-deposition damage:')], 
    [sg.Radio(text, "Radio2", enable_events=True, size=(20, 1), key=f"RadioPostDep {i}")
        for i, text in enumerate(PDepLst)],
#Cortication Amount
    [sg.Text('Select cortication type:')], 
    [sg.Radio(text, "Radio3", enable_events=True, size=(20, 1), key=f"RadioCort {i}")
        for i, text in enumerate(CortLst)],
#Butt Type
    [sg.Text('Select butt type:')],
    [sg.Radio(text, "Radio4", enable_events=True, size=(20, 1), key=f"RadioButt {i}")
        for i, text in enumerate(ButtLst)],
#Cortex Type
    [sg.Text('Select Cortex type:')],
    [sg.Radio(text, "Radio5", enable_events=True, size=(20, 1), key=f"RadioCortType {i}")
        for i, text in enumerate(CortypeLst)],
#Cortex Thickness
    [sg.Text('SelectCortex thickness:')],
    [sg.Radio(text, "Radio6", enable_events=True, size=(20, 1), key=f"RadioCortThick {i}")
        for i, text in enumerate(CorThickLst)],
    [sg.Text('Other Details', size=(15,1)), sg.InputText(key='Other Details')],
 
    
    [sg.Submit(), sg.Push(), sg.Button('Clear'), sg.Exit()]
]

window = sg.Window('Jacobi: Lithic Analyis Data Entry Tool', layout)

def clear_input():
    for key in values:
        window[key]('')
    return None

while True:
    event, values = window.read()
    if event == sg.WIN_CLOSED or event == 'Exit':
        break
    if event == 'Clear':
        clear_input()
#    if event.startswith("RadioSite"):
#        text = window[event].Text
#        print(text)
             
#        print(f"Site:{values[0]}")               

#    strx=""
#    for val in values:
#        if window[key]==True:
#            strx=strx+ " "+ val+","
#            print(strx)
#    elif event.startswith("RadioSite"):
#        Site_text = window[event].Text
#        #print(text)       
#    elif event.startswith("RadioCort"):
#        Cort_text = window[event].Text
#        #print(text)
#    elif event.startswith("RadioButt"):
#        Butt_text = window[event].Text
#        #print(text)
#    elif event.startswith("RadioCortType"):
#        CortType_text = window[event].Text
#        #print(text)
#    elif event.startswith("RadioCortThick"):
#        CortThick_text = window[event].Text
#        #print(text)
#    SF_Number = values["SF_Number"]
#    Radio_list = SF_Number, Site_text, Cort_text, Butt_text, CortType_text, CortThick_text
#    OtherDetails = values["Other Details"]
    
#    final_list = [SF_Number, Radio_list, OtherDetails]
#    print(final_list)

    if event == 'Submit':
        dftest = [values["RadioSite"].Text]
        print(dftext)
        df = df.append(values, ignore_index=True)
        df.to_excel(EXCEL_FILE, index=False)
        sg.popup('Data saved!')
        clear_input()
window.close()
exit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-7b87a036e484> in <module>
#     101
#     102     if event == 'Submit':
# --> 103         dftest = [values["RadioSite"].Text]
#     104         print(dftext)
#     105         df = df.append(values, ignore_index=True)
#
# KeyError: 'RadioSite'

# %%
col1 = [radios]
col2 = [radios]

layout = [sg.Column(col1),sg.VerticalSeparator(), sg.Col(col2)],

# %%
#    [sg.Radio(text, "Radio1", enable_events=True, key=f"Radio1 {j}")
#        for j, text in enumerate(CatLst)],
#    [sg.Push()],  
#    [sg.Radio(text, "Radio2", enable_events=True, key=f"Radio3 {k}")
#        for k, text in enumerate(PDepLst)],
#    [sg.Push()],  
#    [sg.Text('Other Details', size=(15,1)), sg.InputText(key='Other Details')],

    #    [sg.Text('Site', size=(15,1)),
#                            sg.Checkbox('Site 1', key='Site 1'),
#                            sg.Checkbox('Site 2', key='Site 2'),
#                            sg.Checkbox('Site 3', key='Site 3'),
#                            sg.Checkbox('Site 4', key='Site 4'),
#                            sg.Checkbox('Site 5', key='Site 5'),
#                            sg.Checkbox('Site 6', key='Site 6'),
#                            sg.Checkbox('Site 7', key='Site 7'),
#                            sg.Checkbox('Site Other', key='Site Other')],  
#    [sg.Text('Post-depositional damage', size=(15,1)),
#                            sg.Checkbox('1. Fresh', key='1. Fresh'),
#                            sg.Checkbox('2.	Slight post depositional damage', key='2. Slight post depositional damage'),
#                            sg.Checkbox('3.	Moderate post depositional damage', key='3. Moderate post depositional damage'),
#                            sg.Checkbox('4.	Heavy post depositional damage', key='4. Heavy post depositional damage'),
#                            sg.Checkbox('5.	Plough damaged', key='5. Plough damaged'),
#                            sg.Checkbox('6.	Rolled', key='6. Rolled'),
#                            sg.Checkbox('7.	Glossed', key='7. Glossed'),
#                            sg.Checkbox('8.	Modern damage', key='8. Modern damage')],          
#    [sg.Text('Cortication', size=(15,1)),
#                            sg.Checkbox('1.	No cortication', key='1. No cortication'),
#                            sg.Checkbox('2.	Light cortication', key='2. Light cortication'),
#                            sg.Checkbox('3.	Moderate cortication', key='3. Moderate cortication'),
#                            sg.Checkbox('4.	Heavy cortication', key='4. Heavy cortication'),
#                            sg.Checkbox('5.	Very heavy cortication', key='5. Very heavy cortication'),
#                            sg.Checkbox('6.	Iron stained', key='6. Iron stained')],    
#    [sg.Text('Butt type', size=(15,1)),
#                            sg.Checkbox('1. Cortical (cortex)', key='1. Cortical (cortex)'),
#                            sg.Checkbox('2. Plain (unaltered inner flint)', key='2. Plain (unaltered inner flint)'),
#                            sg.Checkbox('3. Dihedral (2 scars)', key='3. Dihedral (2 scars)'),
#                            sg.Checkbox('4. Faceted (more than 2 scars)', key='4.	Faceted (more than 2 scars)'),
#                            sg.Checkbox('5. Linear (very narrow and usually quite long)', key='5. Linear (very narrow and usually quite long)'),
#                            sg.Checkbox('6. Shattered', key='6.	Shattered'),
#                            sg.Checkbox('7. Thermal (old recorticated or patinated surface)', key='7. Thermal (old recorticated or patinated surface)'),
#                            sg.Checkbox('8. Punctiform', key='8. Punctiform'),
#                            sg.Checkbox('9. Modified (retouched or otherwise altered)', key='9. Modified (retouched or otherwise altered)'),
#                            sg.Checkbox('10. Indeterminate (if you can’t decide or it doesn’t fit any of the above)', key='10. Indeterminate (if you can’t decide or it doesn’t fit any of the above)')],    
#    [sg.Text('Cortex type', size=(15,1)),
#                            sg.Checkbox('1. Chalk – thick, creamy white, chalky', key='1. Chalk – thick, creamy white, chalky'),
#                            sg.Checkbox('2. Weathered Chalk – like above but clearly worn and probably thin or moderate in thickness', key='2. Weathered Chalk – like above but clearly worn and probably thin or moderate in thickness'),
#                            sg.Checkbox('3. Weathered – Similar to WC above, will be rough to the touch but clearly ground down.', key='3. Weathered – Similar to WC above, will be rough to the touch but clearly ground down.'),
#                            sg.Checkbox('4. Rolled – typical beach pebble/ river gravel flint, smooth', key='4. Rolled – typical beach pebble/ river gravel flint, smooth'),
#                            sg.Checkbox('5.	Thermal – re-corticated old surface, often will be in', key='5.	Thermal – re-corticated old surface, often will be in'),
#                            sg.Checkbox('6. Indeterminate', key='6. Indeterminate'),
#                            sg.Checkbox('7. Banded -eg. Bullhead flint', key='7.Banded -eg. Bullhead flint')],
#    [sg.Text('Cortex thickness', size=(15,1)),
#                            sg.Checkbox('1. Thin – up to 2mm thick (judge don’t measure)', key='1. Thin – up to 2mm thick (judge don’t measure)'),
#                            sg.Checkbox('2.	Moderate 2-4mm thickness', key='2.	Moderate 2-4mm thickness'),
#                            sg.Checkbox('3.	Thick 4-10mm', key='3.	Thick 4-10mm'),
#                            sg.Checkbox('4.	Very thick, greater than 10mm', key='4.	Very thick, greater than 10mm')],

# %%
#    [sg.Text('Site', size=(15,1)), sg.Combo(['Site 1','Site 2','Site 3','Site 4','Site 5','Site 6','Site 7','Other'], key='Site')],   
#    [sg.Text('Category', size=(15,1)), sg.Combo(['1. Flake', '2. Blade', '3. Bladelet','4. Blake-like flake (DO NOT USE)','5. Irregular Waste','6. Chip','7. Microburin','8. Burin spall','9. Rejuvenation flake','10. Core tablet','11. Rejuvenation flake other','12. Levallois flake','13. Janus flake (= thinning)','14. Axe working flake','15. Flake from ground implement','16. Single platform blade core','17. Opposed platform blade core','18. Other Blade core','19. Tested nodule/ bashed lump','20. Single platform flake core','21. Multiplatform flake core','22. Keeled non-discoidal flake core','23. Levallois/ other discoidal flake core','24. Unclassifiable/ fragmentary core','25. Microlith','26. Petit tranchet arrowhead','27. Leaf arrowhead','28. Chisel arrowhead','29. Oblique arrowhead','30. Barbed and tanged arrowhead','31. Triangular arrowhead','32. Hollow-based arrowhead','33. Laurel leaf','34. Unfinished arrowhead/blank','35. Fragmentary/unclass/other arrowhead','36. End scraper','37. Side scraper','38. End and side scraper','39. Disc scraper','40. Thumbnail scraper','41. Scraper on a non-flake blank','42. Other scraper','43. Awl','44. Piercer','45. Spurred piece','46. Other borer','47. Serrated flake','48. Saw','49. Denticulate','50. Notch','51. Backed knife','52. Scale flaked knife','53. Plano-convex knife','54. Other knife','55. Flake retouched','56. Single-piece sickle','57. Fabricator','58. Axe','59. Other heavy implement','60. Misc retouch','61. Other retouch','62. Burnt unworked','63. Hammerstone','64. Natural','65. Core on a flake','66. Gun flint','67. Axe sharpening flake','68. Sieved chips 10-4mm','69. Sieved chips 4-2mm','70. Sieved chips','71. Bruised blade/flake','72. Burin','73. Blade crested','74. Blade retouched','75. End truncation straight','76. End truncation oblique','77. Backed bladelet','78. Bipolar core'], key='Category')],
#    [sg.Text('Post-depositional damage', size=(15,1)), sg.Combo(['1. Fresh','2. Slight post depositional damage', '3. Moderate post depositional damage','4. Heavy post depositional damage','5.	Plough damaged','6.	Rolled','7.	Glossed','8. Modern damage'], key='Post-depositional damage')],
#    [sg.Text('Cortication', size=(15,1)), sg.Combo(['1. No cortication','2. Light cortication','3. Moderate cortication','4. Heavy cortication','5. Very heavy cortication','6. Iron stained'], key='Cortication')],
#    [sg.Text('Butt type', size=(15,1)), sg.Combo(['1. Cortical (cortex)','2. Plain (unaltered inner flint)','3. Dihedral (2 scars)','4. Faceted (more than 2 scars)','5. Linear (very narrow and usually quite long)','6. Shattered','7. Thermal (old recorticated or patinated surface)','8. Punctiform','9. Modified (retouched or otherwise altered)','10. Indeterminate (if you can’t decide or it doesn’t fit any of the above)'], key='Butt type')],   
#    [sg.Text('Cortex type', size=(15,1)), sg.Combo(['1. Chalk – thick, creamy white, chalky', '2. Weathered Chalk – like above but clearly worn and probably thin or moderate in thickness','3. Weathered – Similar to WC above, will be rough to the touch but clearly ground down.','4. Rolled – typical beach pebble/ river gravel flint, smooth','5. Thermal – re-corticated old surface, often will be in','6. Indeterminate','7. Banded -eg. Bullhead flint'], key='Cortex type')], 
#    [sg.Text('Cortex thickness', size=(15,1)), sg.Combo(['1. Thin – up to 2mm thick (judge don’t measure)', '2.	Moderate 2-4mm thickness', '3.	Thick 4-10mm', '4.	Very thick, greater than 10mm'], key='Cortex thickness')],
#    [sg.Text('Other Details', size=(15,1)), sg.InputText(key='Other Details')],
